# %%
# %run ./01_data_prep.ipynb
# %run ./utils.ipynb

# %%
import numpy as np
from sklearn.decomposition import PCA

# %%
pca = PCA()
reduced_data = PCA(n_components=2).fit_transform(X_train)

# %%
from sklearn.linear_model import SGDClassifier
import matplotlib.pyplot as plt

model = SGDClassifier(alpha=0.01)

plot_learning_curve(model, "SGD Learning Curve", reduced_data, y_train, n_jobs=2)
plt.savefig("SGD Learning Curve.png")
